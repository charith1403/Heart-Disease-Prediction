# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("heart_disease.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
sns.countplot(x='TenYearCHD', data=df)
# Out:
# <Axes: xlabel='TenYearCHD', ylabel='count'>

# %%
sns.countplot(x= 'male', data= df)
plt.show()

# %%
sns.countplot(x= 'diabetes', data=df)
plt.show()

# %%
sns.countplot(x='totChol', data=df)
plt.show()

# %%
plt.scatter(df['totChol'], df['TenYearCHD'])

# %%
plt.scatter(df['cigsPerDay'], df['TenYearCHD'], color='orange')
plt.xlabel('Cigarettes per day')
plt.ylabel('Ten year Coronary Heart Disease')
# Out:
# Text(0, 0.5, 'Ten year Coronary Heart Disease')

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='age', y='TenYearCHD', data= df)
plt.xlabel('age')
plt.ylabel('Ten year CHD')
# Out:
# Text(0, 0.5, 'Ten year CHD')

# %%
sns.pairplot(df[['BMI', 'TenYearCHD']])

# %%
plt.figure(figsize=(10,7))
sns.pairplot(df)

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot= True)
# Out:
# <Axes: >

# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# Dropping the irrelevant attributes.

# %%
df1= df.drop(['education', 'currentSmoker'], axis='columns')
df1.head()
# Out:
#    male  age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 0     1   39         0.0     0.0                0             0         0
# 1     0   46         0.0     0.0                0             0         0
# 2     1   48        20.0     0.0                0             0         0
# 3     0   61        30.0     0.0                0             1         0
# 4     0   46        23.0     0.0                0             0         0
#
#    totChol  sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD
# 0    195.0  106.0   70.0  26.97       80.0     77.0           0
# 1    250.0  121.0   81.0  28.73       95.0     76.0           0
# 2    245.0  127.5   80.0  25.34       75.0     70.0           0
# 3    225.0  150.0   95.0  28.58       65.0    103.0           1
# 4    285.0  130.0   84.0  23.10       85.0     85.0           0

# %% [markdown]
# Check for missing values.

# %%
df1.isna().sum()
# Out:
# male                 0
# age                  0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df1= df1.fillna({
    'BPMeds': 0,
    'cigsPerDay': 0
})
df1.isna().sum()
# Out:
# male                 0
# age                  0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
missing= df[df['totChol'].isna()==True]
print(missing)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 42       0   52        1.0              0         0.0     1.0
# 154      0   38        3.0              1         3.0     1.0
# 247      0   40        2.0              1        20.0     0.0
# 429      1   65        NaN              0         0.0     0.0
# 567      0   66        2.0              1        15.0     0.0
# 577      0   37        2.0              1        30.0     0.0
# 609      0   41        1.0              1        30.0     0.0
# 673      0   58        1.0              1        20.0     0.0
# 822      0   62        2.0              1        30.0     0.0
# 834      0   59        1.0              0         0.0     0.0
# 871      0   58        2.0              1         3.0     0.0
# 951      0   49        2.0              1        15.0     0.0
# 1105     0   35        3.0              0         0.0     0.0
# 1122     0   67        1.0              1         6.0     NaN
# ...

# %%
df['totChol'][42]
# Out:
# nan

# %%
df1=df1.fillna({
    'totChol': df1['totChol'].mean()
})
df1.isna().sum()
df1['totChol'][42]
# Out:
# 236.69952267303103

# %%
df1=df1.fillna({
    'glucose': df1['glucose'].mean(),
    'BMI': df1['BMI'].mean(),
    'heartRate': df1['heartRate'].mean()
})

df1.isna().sum()
# Out:
# male               0
# age                0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df1.describe()
# Out:
#               male          age   cigsPerDay       BPMeds  prevalentStroke  \
# count  4240.000000  4240.000000  4240.000000  4240.000000      4240.000000
# mean      0.429245    49.580189     8.944340     0.029245         0.005896
# std       0.495027     8.572942    11.904777     0.168513         0.076569
# min       0.000000    32.000000     0.000000     0.000000         0.000000
# 25%       0.000000    42.000000     0.000000     0.000000         0.000000
# 50%       0.000000    49.000000     0.000000     0.000000         0.000000
# 75%       1.000000    56.000000    20.000000     0.000000         0.000000
# max       1.000000    70.000000    70.000000     1.000000         1.000000
#
#        prevalentHyp     diabetes      totChol        sysBP        diaBP  \
# count   4240.000000  4240.000000  4240.000000  4240.000000  4240.000000
# mean       0.310613     0.025708   236.699523   132.354599    82.897759
# std        0.462799     0.158280    44.327521    22.033300    11.910394
# ...

# %%
sns.boxplot(df1['totChol'])
# Out:
# <Axes: ylabel='totChol'>

# %%
df2= df1.drop(df1[df1['totChol']>500].index)            #drops the outlier rows
sns.boxplot(df2['totChol'])
# Out:
# <Axes: ylabel='totChol'>

# %%
df2.describe()
# Out:
#               male          age   cigsPerDay       BPMeds  prevalentStroke  \
# count  4238.000000  4238.000000  4238.000000  4238.000000      4238.000000
# mean      0.429212    49.579283     8.946437     0.029259         0.005899
# std       0.495022     8.574857    11.906794     0.168552         0.076587
# min       0.000000    32.000000     0.000000     0.000000         0.000000
# 25%       0.000000    42.000000     0.000000     0.000000         0.000000
# 50%       0.000000    49.000000     0.000000     0.000000         0.000000
# 75%       1.000000    56.000000    20.000000     0.000000         0.000000
# max       1.000000    70.000000    70.000000     1.000000         1.000000
#
#        prevalentHyp     diabetes      totChol        sysBP        diaBP  \
# count   4238.000000  4238.000000  4238.000000  4238.000000  4238.000000
# mean       0.310288     0.025484   236.505421   132.342378    82.894172
# std        0.462666     0.157608    43.415189    22.031297    11.911817
# ...

# %%
# Separate features and target
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from xgboost import XGBClassifier



X = df2.drop(columns=['TenYearCHD'])
y = df2['TenYearCHD']

# Normalize numerical features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Step 2: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# !pip install catboost

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pandas as pd
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Step 3: Define Models
models = {
    'Gradient Boosting': GradientBoostingClassifier(),
    'Neural Network': MLPClassifier(max_iter=500),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'LightGBM': LGBMClassifier(force_row_wise=True),
    'CatBoost': CatBoostClassifier(verbose=0)
}

# Define cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Step 4: Train, Evaluate, and Cross-Validate Models
results = []
for name, model in models.items():
    print(f"Evaluating {name}...")

    # Cross-validation scores
    accuracy_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv)
    precision_scores = cross_val_score(model, X_train, y_train, scoring='precision', cv=cv)
    recall_scores = cross_val_score(model, X_train, y_train, scoring='recall', cv=cv)
    f1_scores = cross_val_score(model, X_train, y_train, scoring='f1', cv=cv)
    roc_auc_scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv)

    # Train the model
    model.fit(X_train, y_train)

    # Predict on test set
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    # Evaluate the model on test set
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba) if y_pred_proba is not None else None

    results.append({
        'Model': name,
        'CV Accuracy': accuracy_scores.mean(),
        'CV Precision': precision_scores.mean(),
        'CV Recall': recall_scores.mean(),
        'CV F1 Score': f1_scores.mean(),
        'CV ROC AUC': roc_auc_scores.mean(),
        'Test Accuracy': accuracy,
        'Test Precision': precision,
        'Test Recall': recall,
        'Test F1 Score': f1,
        'Test ROC AUC': roc_auc
    })

# Step 5: Display Results
results_df = pd.DataFrame(results)
print(results_df.sort_values(by='CV Accuracy', ascending=False))
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Evaluating Gradient Boosting...
# Evaluating Neural Network...
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Define hyperparameter grids for each model
param_grids = {
    'Gradient Boosting': {
        'learning_rate': [0.01, 0.1, 0.2],
        'n_estimators': [100, 200],
        'max_depth': [3, 5]
    },
    'Neural Network': {
        'hidden_layer_sizes': [(50, 50), (100, 50)],
        'activation': ['relu', 'tanh'],
        'solver': ['adam', 'sgd']
    },
    'XGBoost': {
        'learning_rate': [0.01, 0.1, 0.2],
        'n_estimators': [100, 200],
        'max_depth': [3, 5]
    },
    'LightGBM': {
        'learning_rate': [0.01, 0.1, 0.2],
        'n_estimators': [100, 200],
        'num_leaves': [31, 50]
    },
    'CatBoost': {
        'learning_rate': [0.01, 0.1],
        'depth': [4, 6],
        'iterations': [100, 200]
    }
}

# Perform hyperparameter tuning for each model
best_params = {}
for name, model in models.items():
    print(f"Hyperparameter tuning for {name}...")
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grids[name],
        scoring='accuracy',
        cv=3,  # 3-fold cross-validation
        n_jobs=-1,
        verbose=1
    )
    grid_search.fit(X_train, y_train)
    best_params[name] = grid_search.best_params_
    print(f"Best parameters for {name}: {best_params[name]}")

# Print all best parameters
print("\nBest Parameters for All Models:")
for model_name, params in best_params.items():
    print(f"{model_name}: {params}")
# Out:
# Hyperparameter tuning for Gradient Boosting...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best parameters for Gradient Boosting: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200}
# Hyperparameter tuning for Neural Network...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Best parameters for Neural Network: {'activation': 'tanh', 'hidden_layer_sizes': (50, 50), 'solver': 'sgd'}
# Hyperparameter tuning for XGBoost...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters for XGBoost: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200}
# Hyperparameter tuning for LightGBM...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# ...

# %%
# Reinitialize models with best parameters
for name, params in best_params.items():
    if name == 'CatBoost':
        models[name] = CatBoostClassifier(**params, verbose=0)
    elif name == 'Gradient Boosting':
        models[name] = GradientBoostingClassifier(**params)
    elif name == 'Neural Network':
        models[name] = MLPClassifier(**params, max_iter=500)
    elif name == 'XGBoost':
        models[name] = XGBClassifier(**params, use_label_encoder=False, eval_metric='logloss')
    elif name == 'LightGBM':
        models[name] = LGBMClassifier(**params, force_row_wise=True)

# %%
# Train and Evaluate Models with Tuned Parameters
results = []
for name, model in models.items():
    print(f"Evaluating {name} with best parameters...")

    # Train the model
    model.fit(X_train, y_train)

    # Predict on test set
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    # Evaluate the model on test set
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba) if y_pred_proba is not None else None

    results.append({
        'Model': name,
        'Test Accuracy': accuracy,
        'Test Precision': precision,
        'Test Recall': recall,
        'Test F1 Score': f1,
        'Test ROC AUC': roc_auc
    })

# Display Results
results_df = pd.DataFrame(results)
print(results_df.sort_values(by='Test Accuracy', ascending=False))
# Out:
# Evaluating Gradient Boosting with best parameters...
# Evaluating Neural Network with best parameters...
# Evaluating XGBoost with best parameters...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:29:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Evaluating LightGBM with best parameters...
# [LightGBM] [Info] Number of positive: 515, number of negative: 2875
# [LightGBM] [Info] Total Bins 987
# [LightGBM] [Info] Number of data points in the train set: 3390, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.151917 -> initscore=-1.719641
# [LightGBM] [Info] Start training from score -1.719641
# Evaluating CatBoost with best parameters...
#                Model  Test Accuracy  Test Precision  Test Recall  \
# 3           LightGBM       0.850236        1.000000     0.007812
# ...

# %%
# GPT4 MODEL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load the dataset
file_path = 'enhanced_heart_disease_with_medical_history.csv'
df = pd.read_csv(file_path)


df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
# ...

# %%
df['MedicalHistory']
# Out:
# 0       The patient is male and is 39.0 years old. No ...
# 1       The patient is female and is 46.0 years old. N...
# 2       The patient is male and is 48.0 years old. No ...
# 3       The patient is female and is 61.0 years old. H...
# 4       The patient is female and is 46.0 years old. N...
#                               ...
# 4235    The patient is female and is 48.0 years old. N...
# 4236    The patient is female and is 44.0 years old. N...
# 4237    The patient is female and is 52.0 years old. N...
# 4238    The patient is male and is 40.0 years old. Has...
# 4239    The patient is female and is 39.0 years old. N...
# Name: MedicalHistory, Length: 4240, dtype: object

# %%
import pandas as pd
import openai
import time

# Replace <API_KEY> with your OpenAI API Key
openai.api_key = "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"

# Load the dataset
file_path = "enhanced_heart_disease_with_medical_history.csv"
df = pd.read_csv(file_path)

# Assuming X_test is already defined and matches indices
if 'X_test' in locals():
    df_test = df.loc[X_test.index].copy()  # Use .loc and .copy() to avoid SettingWithCopyWarning
else:
    raise ValueError("X_test is not defined. Ensure it is initialized properly.")

# Create GPT-4 prompts based on the MedicalHistory column
df_test['GPT4_Prompt'] = df_test['MedicalHistory'].apply(
    lambda x: f"Based on the following medical history, predict if the patient is at high risk of heart disease: {x}. Restrict the output to 0 or 1. 0 means no-risk 1 is high-risk"
)

# Function to get GPT-4 predictions with retry mechanism for rate limits
def get_gpt4_prediction(prompt, retries=3):
    for attempt in range(retries):
        try:
            response = openai.ChatCompletion.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are an assistant predicting heart disease risk based on medical history."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=10,
                temperature=0
            )
            return response['choices'][0]['message']['content'].strip()
        except openai.error.RateLimitError:
            print(f"Rate limit reached for prompt: {prompt}. Retrying in 10 seconds...")
            time.sleep(10)
        except Exception as e:
            print(f"Error for prompt: {prompt}\n{e}")
            return "Error"
    return "Error"

# Apply GPT-4 predictions
df_test['GPT4_Prediction'] = df_test['GPT4_Prompt'].apply(get_gpt4_prediction)

# Display a preview of the results
print(df_test[['MedicalHistory', 'GPT4_Prediction']].head())

# Save the dataset with predictions
output_file = "gpt4_predictions1.csv"
df_test.to_csv(output_file, index=False)
print(f"Predictions saved to {output_file}")
# Out:
# Rate limit reached for prompt: Based on the following medical history, predict if the patient is at high risk of heart disease: The patient is female and is 56.0 years old. No history of hypertension. No history of stroke. No diabetes. Not on blood pressure medications.. Restrict the output to 0 or 1. 0 means no-risk 1 is high-risk. Retrying in 10 seconds...
# Rate limit reached for prompt: Based on the following medical history, predict if the patient is at high risk of heart disease: The patient is female and is 56.0 years old. Has a history of hypertension. No history of stroke. No diabetes. Not on blood pressure medications.. Restrict the output to 0 or 1. 0 means no-risk 1 is high-risk. Retrying in 10 seconds...
# ...

# %%
df_test['GPT4_Prediction'].value_counts()
# Out:
# GPT4_Prediction
# 0    557
# 1    291
# Name: count, dtype: int64

# %%
df_test.head()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3188     1   63        1.0              0         0.0     0.0
# 764      1   45        3.0              0         0.0     0.0
# 3264     0   51        1.0              1         2.0     0.0
# 1967     1   45        3.0              1        30.0     0.0
# 2185     0   45        2.0              1         3.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3188                0             1         0    190.0  148.0   90.0  27.13
# 764                 0             0         0    162.0  125.0   89.0  27.98
# 3264                0             0         0    261.0  127.0   81.0  20.24
# 1967                0             0         0    250.0  126.0   89.5  28.68
# 2185                0             0         0    250.0  130.0   80.0  20.24
#
#       heartRate  glucose  TenYearCHD  \
# 3188       72.0     86.0           0
# 764        85.0     83.0           0
# ...

# %%
df_test['TenYearCHD'].value_counts()
# Out:
# TenYearCHD
# 0    724
# 1    124
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Ensure GPT4_Prediction column is numeric for comparison
df_test['GPT4_Prediction'] = pd.to_numeric(df_test['GPT4_Prediction'], errors='coerce')


y_test=df_test['TenYearCHD']

# Assuming y_test contains the true labels
if 'y_test' in locals():
    # Generate the classification report
    report = classification_report(y_test, df_test['GPT4_Prediction'], target_names=["No Risk", "High Risk"])
    accuracy = accuracy_score(y_test, df_test['GPT4_Prediction'])
    cm = confusion_matrix(y_test, df_test['GPT4_Prediction'])

    # Display metrics
    print("Classification Report:\n", report)
    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", cm)

    # Optionally save the metrics to a text file
    with open("classification_report.txt", "w") as f:
        f.write(f"Classification Report:\n{report}\n")
        f.write(f"Accuracy: {accuracy}\n")
        f.write(f"Confusion Matrix:\n{cm}\n")
else:
    raise ValueError("y_test is not defined. Ensure it is initialized properly.")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      No Risk       0.90      0.69      0.78       724
#    High Risk       0.24      0.56      0.33       124
#
#     accuracy                           0.67       848
#    macro avg       0.57      0.62      0.56       848
# weighted avg       0.80      0.67      0.72       848
#
# Accuracy: 0.6733490566037735
# Confusion Matrix:
#  [[502 222]
#  [ 55  69]]

# %%
df_test.shape
# Out:
# (848, 19)

# %%
pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiohttp, requests, tqdm
# Required-by:
